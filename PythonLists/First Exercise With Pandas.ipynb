# %%
import pandas as pd
import html5lib
url = "https://en.wikipedia.org/wiki/List_of_serving_generals_of_the_Pakistan_Army"
dfs = pd.read_html(url)
dfs[3]
Armylist =[dfs]

# %%
print(Armylist)
# Out:
# [[    0                                                  1
# 0 NaN  This article has an unclear citation style. Th...,                                         Pakistan Army
# 0                                          Leadership
# 1   Chief of Army Staff Chairman Joint Chiefs of S...
# 2                         Organisation and components
# 3   Structure of the Pakistan Army Frontier Corps ...
# 4                                       Installations
# 5   General Headquarters Pakistan Military Academy...
# 6                                           Personnel
# 7             Army Ranks of Pakistan Serving generals
# 8                                           Equipment
# 9                      Equipment of the Pakistan Army
# 10                             History and traditions
# 11  Military history of Pakistan UN Peacekeeping M...
# 12                     Awards, decorations and badges
# 13             Awards and Decorations Nishan-e-Haider
# ...

# %%
print(Armylist[1])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-33-a193080d85b8> in <module>
# ----> 1 print(Armylist[1])
#
# IndexError: list index out of range
